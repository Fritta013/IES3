# %% [markdown]
# <a href="https://colab.research.google.com/github/Fritta013/IES3/blob/master/pasta_custom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Get the system runtime details**

# %%
# %cat /etc/lsb-release
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=18.04
# DISTRIB_CODENAME=bionic
# DISTRIB_DESCRIPTION="Ubuntu 18.04.5 LTS"

# %% [markdown]
# **Update the Repo list (Not the system**

# %%
# !apt-get update
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:7 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Ign:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages
# ...

# %% [markdown]
# **Show the current working directory**

# %%
# %pwd
# Out:
# '/content'

# %% [markdown]
# **Unzip the darknet zip file to the /content folder**

# %%
# !unzip "/content/drive/MyDrive/custom_pasta_model/darknet.zip"
# Out:
# Archive:  /content/drive/MyDrive/custom_pasta_model/darknet.zip
#    creating: darknet/.circleci/
#   inflating: darknet/.circleci/config.yml
#   inflating: darknet/.gitignore
#   inflating: darknet/.travis.yml
#    creating: darknet/3rdparty/
#    creating: darknet/3rdparty/pthreads/
#    creating: darknet/3rdparty/pthreads/bin/
#   inflating: darknet/3rdparty/pthreads/bin/pthreadGC2.dll
#   inflating: darknet/3rdparty/pthreads/bin/pthreadVC2.dll
#    creating: darknet/3rdparty/pthreads/include/
#   inflating: darknet/3rdparty/pthreads/include/pthread.h
#   inflating: darknet/3rdparty/pthreads/include/sched.h
#   inflating: darknet/3rdparty/pthreads/include/semaphore.h
#    creating: darknet/3rdparty/pthreads/lib/
#   inflating: darknet/3rdparty/pthreads/lib/libpthreadGC2.a
#   inflating: darknet/3rdparty/pthreads/lib/pthreadVC2.lib
#    creating: darknet/3rdparty/stb/
#    creating: darknet/3rdparty/stb/include/
#   inflating: darknet/3rdparty/stb/include/stb_image.h
# ...

# %% [markdown]
# **change directory to /content/darknet**

# %%
# %cd /content/darknet
# Out:
# /content/darknet

# %% [markdown]
# **install dos2unix**

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 39 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 1s (562 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package dos2unix.
# ...

# %% [markdown]
# **convert all files in darknet to unix encoding**

# %%
# !find . -type f -print0 | xargs -0 dos2unix
# Out:
# Streaming output truncated to the last 5000 lines.
# dos2unix: Skipping binary file ./data/labels/74_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/54_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/120_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/104_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/83_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/72_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/42_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/119_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/112_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# ...

# %% [markdown]
# **Give executable permission for files in /content/darkent**

# %%
# !chmod +x /content/darknet

# %% [markdown]
# **Verify the current working directory**

# %%
# %pwd
# Out:
# '/content'

# %% [markdown]
# **Change working directory to content/darknet**

# %%
# %cd /content/darknet
# Out:
# /content/darknet

# %%
# %pwd
# Out:
# '/content/darknet'

# %%
# !chmod +x /content/darknet

# %%
# %pwd
# Out:
# '/content/darknet'

# %% [markdown]
# **compile the darknet framework**

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %% [markdown]
# **Test the darknet frameork with sample object detection**

# %%
# !./darknet detector test cfg/coco.data cfg/yolov4.cfg yolov4.weights data/person.jpg
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
# ...

# %% [markdown]
# The results of the compilations are volative, we need to saves the results in a backup folder

# %% [markdown]
# **remove the default backup folder of darknet in runtime**

# %%
# !rm /content/darknet/backup -r
# Out:
# rm: cannot remove '/content/darknet/backup': No such file or directory

# %% [markdown]
# **Create a symbolic link from runtime darknet folder to google drive backup folder with the name 'backup'**

# %%
# !ln -s /content/drive/'My Drive'/pasta_weights/backup /content/darknet

# %% [markdown]
# **check the directory**

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd /content/darknet
# Out:
# [Errno 2] No such file or directory: '/content/darknet'
# /content

# %% [markdown]
# **proceed with the pasta recognition training using the pasta dataset**

# %% [markdown]
# -map parameter??? to generate a chart .png .image to check the mean average processing to show the loss and mean average procesing

# %%
# !./darknet detector train pasta_data/pasta.data pasta_yolov4.cfg yolov4.conv.137 -map -dont_show
# Out:
# /bin/bash: ./darknet: No such file or directory
